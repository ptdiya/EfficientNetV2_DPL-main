# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.hub
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

class SEBlock(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SEBlock, self).__init__()
        self.fc1 = nn.Linear(channel, channel // reduction, bias=True)
        self.relu = nn.ReLU(inplace=True)
        self.fc2 = nn.Linear(channel // reduction, channel, bias=True)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        batch, channels, _, _ = x.size()
        y = F.adaptive_avg_pool2d(x, 1).view(batch, channels)
        y = self.fc1(y)
        y = self.relu(y)
        y = self.fc2(y)
        y = self.sigmoid(y).view(batch, channels, 1, 1)
        return x * y.expand_as(x)

class UpsampleModule(nn.Module):
    def __init__(self, in_channels=3, out_channels=3):
        super(UpsampleModule, self).__init__()
        self.upsample = nn.Sequential(
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True),  # 32 -> 64
            nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            SEBlock(64),
            
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True),  # 64 -> 128
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            SEBlock(128),
            
            nn.Upsample(scale_factor=1.75, mode='bilinear', align_corners=True),  # 128 * 1.75 ≈ 224
            nn.Conv2d(128, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            SEBlock(out_channels)
        )
        
    def forward(self, x):
        return self.upsample(x)

# %%
class EfficientNetV2_FeatureExtraction(nn.Module):
    def __init__(self, weight_path_small='Weights/efficientnet_v2_s_cifar10.pth', num_classes=10):
        super(EfficientNetV2_FeatureExtraction, self).__init__()
        
        #upsampling module: 32x32 -> 224x224
        self.upsampler = UpsampleModule(in_channels=3, out_channels=3)
        
        model_name_small = 'efficientnet_v2_s'
        self.efficientnet = torch.hub.load('hankyul2/EfficientNetV2-pytorch', model_name_small, nclass=num_classes, skip_validation=True)
        
        self.efficientnet.load_state_dict(torch.load(weight_path_small, map_location=torch.device('cpu')))
    def forward(self, x):
        x = self.upsampler(x)
        x = self.efficientnet(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
model = EfficientNetV2_FeatureExtraction(weight_path_small='Weights/efficientnet_v2_s_cifar10.pth', num_classes=10)
model = model.to(device)
# Out:
# /usr/lib/python3/dist-packages/torch/nn/init.py:453: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Using cache found in /home/ubuntu/.cache/torch/hub/hankyul2_EfficientNetV2-pytorch_main
# /tmp/ipykernel_15020/2355223843.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.efficientnet.load_state_dict(torch.load(weight_path_small, map_location=torch.device('cpu')))

# %%
from torch.utils.data import DataLoader, random_split

criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

transform = transforms.ToTensor()

full_train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

train_size = int(0.8 * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size
train_dataset, val_dataset = random_split(full_train_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(42))

print(f"Training samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")

train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=100, shuffle=False, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4, pin_memory=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Training samples: 40000
# Validation samples: 10000
# Test samples: 10000

# %%
import torch.optim as optim

optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()), 
    lr=0.001, 
    weight_decay=0.005
)

scheduler = optim.lr_scheduler.OneCycleLR(
    optimizer, 
    max_lr=0.001, 
    total_steps=20 * len(train_loader), 
    anneal_strategy='linear',
    pct_start=0.3, 
    div_factor=25, 
    final_div_factor=1e4  
)

# %%
import os
from copy import deepcopy

patience = 5
best_val_loss = float('inf')
epochs_no_improve = 0
early_stop = False
best_model_state = deepcopy(model.state_dict())

num_epochs = 20

for epoch in range(num_epochs):
    if early_stop:
        print("Early stopping triggered.")
        break

    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    print(f"\nEpoch {epoch + 1}/{num_epochs}")
    print("-" * 30)

    for batch_idx, (inputs, targets) in enumerate(train_loader, 1):
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()
        scheduler.step()

        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        print(f"Batch [{batch_idx}/{len(train_loader)}] - Loss: {loss.item():.4f}")

    train_loss = running_loss / total
    train_acc = 100. * correct / total

    # Validation Phase
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)

            val_loss += loss.item() * inputs.size(0)
            _, predicted = outputs.max(1)
            val_total += targets.size(0)
            val_correct += predicted.eq(targets).sum().item()

    val_loss /= val_total
    val_acc = 100. * val_correct / val_total

    print(f"Epoch [{epoch + 1}/{num_epochs}] "
          f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% "
          f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_no_improve = 0
        best_model_state = deepcopy(model.state_dict())
        print(f"Validation loss improved to {val_loss:.4f}.")
    else:
        epochs_no_improve += 1
        print(f"No improvement in validation loss for {epochs_no_improve} epoch(s).")
        if epochs_no_improve >= patience:
            print("Early stopping triggered.")
            early_stop = True

model.load_state_dict(best_model_state)
# Out:
# Epoch 1/20
# ------------------------------
# Batch [1/157] - Loss: 1.0709
# Batch [2/157] - Loss: 1.0543
# Batch [3/157] - Loss: 1.0435
# Batch [4/157] - Loss: 1.0774
# Batch [5/157] - Loss: 1.0745
# Batch [6/157] - Loss: 1.0018
# Batch [7/157] - Loss: 1.0699
# Batch [8/157] - Loss: 0.9521
# Batch [9/157] - Loss: 1.0037
# Batch [10/157] - Loss: 0.8448
# Batch [11/157] - Loss: 0.9285
# Batch [12/157] - Loss: 0.8719
# Batch [13/157] - Loss: 0.9145
# Batch [14/157] - Loss: 0.9566
# Batch [15/157] - Loss: 0.8715
# Batch [16/157] - Loss: 0.9654
# Batch [17/157] - Loss: 0.8398
# Batch [18/157] - Loss: 0.8433
# Batch [19/157] - Loss: 0.7801
# Batch [20/157] - Loss: 0.8637
# Batch [21/157] - Loss: 0.7886
# Batch [22/157] - Loss: 0.7989
# Batch [23/157] - Loss: 0.7482
# Batch [24/157] - Loss: 0.7111
# Batch [25/157] - Loss: 0.7317
# Batch [26/157] - Loss: 0.7547
# Batch [27/157] - Loss: 0.8056
# Batch [28/157] - Loss: 0.8213
# Batch [29/157] - Loss: 0.6990
# Batch [30/157] - Loss: 0.7720
# Batch [31/157] - Loss: 0.7290
# Batch [32/157] - Loss: 0.7263
# Batch [33/157] - Loss: 0.6794
# Batch [34/157] - Loss: 0.7027
# Batch [35/157] - Loss: 0.6821
# Batch [36/157] - Loss: 0.7272
# Batch [37/157] - Loss: 0.7386
# Batch [38/157] - Loss: 0.6738
# Batch [39/157] - Loss: 0.6530
# Batch [40/157] - Loss: 0.7212
# Batch [41/157] - Loss: 0.7305
# Batch [42/157] - Loss: 0.6674
# Batch [43/157] - Loss: 0.6752
# Batch [44/157] - Loss: 0.7032
# Batch [45/157] - Loss: 0.6541
# Batch [46/157] - Loss: 0.6811
# Batch [47/157] - Loss: 0.6786
# Batch [48/157] - Loss: 0.6571
# Batch [49/157] - Loss: 0.6610
# Batch [50/157] - Loss: 0.6457
# Batch [51/157] - Loss: 0.6223
# Batch [52/157] - Loss: 0.6439
# Batch [53/157] - Loss: 0.6112
# Batch [54/157] - Loss: 0.6380
# Batch [55/157] - Loss: 0.6629
# Batch [56/157] - Loss: 0.6510
# Batch [57/157] - Loss: 0.6219
# Batch [58/157] - Loss: 0.6275
# Batch [59/157] - Loss: 0.6159
# Batch [60/157] - Loss: 0.6618
# Batch [61/157] - Loss: 0.6707
# Batch [62/157] - Loss: 0.6362
# Batch [63/157] - Loss: 0.6085
# Batch [64/157] - Loss: 0.5892
# Batch [65/157] - Loss: 0.6021
# Batch [66/157] - Loss: 0.6101
# Batch [67/157] - Loss: 0.6284
# Batch [68/157] - Loss: 0.6265
# Batch [69/157] - Loss: 0.5876
# Batch [70/157] - Loss: 0.5799
# Batch [71/157] - Loss: 0.5974
# Batch [72/157] - Loss: 0.6021
# Batch [73/157] - Loss: 0.5961
# Batch [74/157] - Loss: 0.6128
# Batch [75/157] - Loss: 0.6549
# Batch [76/157] - Loss: 0.5613
# Batch [77/157] - Loss: 0.6075
# Batch [78/157] - Loss: 0.5723
# Batch [79/157] - Loss: 0.5917
# Batch [80/157] - Loss: 0.5708
# Batch [81/157] - Loss: 0.5540
# Batch [82/157] - Loss: 0.6071
# Batch [83/157] - Loss: 0.5781
# Batch [84/157] - Loss: 0.5872
# Batch [85/157] - Loss: 0.6149
# Batch [86/157] - Loss: 0.5980
# Batch [87/157] - Loss: 0.5582
# Batch [88/157] - Loss: 0.6009
# Batch [89/157] - Loss: 0.6271
# Batch [90/157] - Loss: 0.5951
# Batch [91/157] - Loss: 0.5711
# Batch [92/157] - Loss: 0.5870
# Batch [93/157] - Loss: 0.5857
# Batch [94/157] - Loss: 0.6071
# Batch [95/157] - Loss: 0.5832
# Batch [96/157] - Loss: 0.5927
# Batch [97/157] - Loss: 0.5874
# Batch [98/157] - Loss: 0.5644
# Batch [99/157] - Loss: 0.5701
# Batch [100/157] - Loss: 0.6092
# Batch [101/157] - Loss: 0.5496
# Batch [102/157] - Loss: 0.5690
# Batch [103/157] - Loss: 0.5462
# Batch [104/157] - Loss: 0.5924
# Batch [105/157] - Loss: 0.6085
# Batch [106/157] - Loss: 0.5740
# Batch [107/157] - Loss: 0.6194
# Batch [108/157] - Loss: 0.5610
# Batch [109/157] - Loss: 0.5897
# Batch [110/157] - Loss: 0.5761
# Batch [111/157] - Loss: 0.5767
# Batch [112/157] - Loss: 0.5445
# Batch [113/157] - Loss: 0.5733
# Batch [114/157] - Loss: 0.5708
# Batch [115/157] - Loss: 0.5529
# Batch [116/157] - Loss: 0.5697
# Batch [117/157] - Loss: 0.5492
# Batch [118/157] - Loss: 0.5695
# Batch [119/157] - Loss: 0.5698
# Batch [120/157] - Loss: 0.5696
# Batch [121/157] - Loss: 0.5322
# Batch [122/157] - Loss: 0.5355
# Batch [123/157] - Loss: 0.5891
# Batch [124/157] - Loss: 0.5582
# Batch [125/157] - Loss: 0.5774
# Batch [126/157] - Loss: 0.6281
# Batch [127/157] - Loss: 0.5482
# Batch [128/157] - Loss: 0.5757
# Batch [129/157] - Loss: 0.6289
# Batch [130/157] - Loss: 0.5590
# Batch [131/157] - Loss: 0.5618
# Batch [132/157] - Loss: 0.5859
# Batch [133/157] - Loss: 0.5594
# Batch [134/157] - Loss: 0.5832
# Batch [135/157] - Loss: 0.5587
# Batch [136/157] - Loss: 0.5799
# Batch [137/157] - Loss: 0.5528
# Batch [138/157] - Loss: 0.5637
# Batch [139/157] - Loss: 0.6069
# Batch [140/157] - Loss: 0.5824
# Batch [141/157] - Loss: 0.5929
# Batch [142/157] - Loss: 0.5541
# Batch [143/157] - Loss: 0.5569
# Batch [144/157] - Loss: 0.5686
# Batch [145/157] - Loss: 0.5279
# Batch [146/157] - Loss: 0.5657
# Batch [147/157] - Loss: 0.6092
# Batch [148/157] - Loss: 0.5415
# Batch [149/157] - Loss: 0.5541
# Batch [150/157] - Loss: 0.5414
# Batch [151/157] - Loss: 0.5850
# Batch [152/157] - Loss: 0.5757
# Batch [153/157] - Loss: 0.5571
# Batch [154/157] - Loss: 0.5558
# Batch [155/157] - Loss: 0.5332
# Batch [156/157] - Loss: 0.5450
# Batch [157/157] - Loss: 0.5562
# Epoch [1/20] Train Loss: 0.6572 | Train Acc: 93.67% Val Loss: 0.5446 | Val Acc: 98.13%
# Validation loss improved to 0.5446.
#
# Epoch 2/20
# ------------------------------
# Batch [1/157] - Loss: 0.5518
# Batch [2/157] - Loss: 0.5112
# Batch [3/157] - Loss: 0.5289
# Batch [4/157] - Loss: 0.5466
# Batch [5/157] - Loss: 0.5562
# Batch [6/157] - Loss: 0.5276
# Batch [7/157] - Loss: 0.5298
# Batch [8/157] - Loss: 0.5539
# Batch [9/157] - Loss: 0.5653
# Batch [10/157] - Loss: 0.5303
# Batch [11/157] - Loss: 0.5623
# Batch [12/157] - Loss: 0.5732
# Batch [13/157] - Loss: 0.5542
# Batch [14/157] - Loss: 0.6091
# Batch [15/157] - Loss: 0.5609
# Batch [16/157] - Loss: 0.5339
# Batch [17/157] - Loss: 0.5270
# Batch [18/157] - Loss: 0.5578
# Batch [19/157] - Loss: 0.5446
# Batch [20/157] - Loss: 0.5182
# Batch [21/157] - Loss: 0.5522
# Batch [22/157] - Loss: 0.5237
# Batch [23/157] - Loss: 0.5303
# Batch [24/157] - Loss: 0.5489
# Batch [25/157] - Loss: 0.5379
# Batch [26/157] - Loss: 0.5570
# Batch [27/157] - Loss: 0.5257
# Batch [28/157] - Loss: 0.5709
# Batch [29/157] - Loss: 0.5654
# Batch [30/157] - Loss: 0.5877
# Batch [31/157] - Loss: 0.5375
# Batch [32/157] - Loss: 0.5598
# Batch [33/157] - Loss: 0.5469
# Batch [34/157] - Loss: 0.5696
# Batch [35/157] - Loss: 0.5439
# Batch [36/157] - Loss: 0.5572
# Batch [37/157] - Loss: 0.5616
# Batch [38/157] - Loss: 0.5338
# Batch [39/157] - Loss: 0.5423
# Batch [40/157] - Loss: 0.5545
# Batch [41/157] - Loss: 0.5482
# Batch [42/157] - Loss: 0.5515
# Batch [43/157] - Loss: 0.5512
# Batch [44/157] - Loss: 0.5255
# Batch [45/157] - Loss: 0.5736
# Batch [46/157] - Loss: 0.5622
# Batch [47/157] - Loss: 0.5362
# Batch [48/157] - Loss: 0.5432
# Batch [49/157] - Loss: 0.5350
# Batch [50/157] - Loss: 0.5354
# Batch [51/157] - Loss: 0.5288
# Batch [52/157] - Loss: 0.5200
# Batch [53/157] - Loss: 0.5297
# Batch [54/157] - Loss: 0.5250
# Batch [55/157] - Loss: 0.5579
# Batch [56/157] - Loss: 0.5416
# Batch [57/157] - Loss: 0.5136
# Batch [58/157] - Loss: 0.5337
# Batch [59/157] - Loss: 0.5488
# Batch [60/157] - Loss: 0.5458
# Batch [61/157] - Loss: 0.5452
# Batch [62/157] - Loss: 0.5352
# Batch [63/157] - Loss: 0.5293
# Batch [64/157] - Loss: 0.5288
# Batch [65/157] - Loss: 0.5111
# Batch [66/157] - Loss: 0.5358
# Batch [67/157] - Loss: 0.5165
# Batch [68/157] - Loss: 0.5320
# Batch [69/157] - Loss: 0.5422
# Batch [70/157] - Loss: 0.5439
# Batch [71/157] - Loss: 0.5335
# Batch [72/157] - Loss: 0.5565
# Batch [73/157] - Loss: 0.5735
# Batch [74/157] - Loss: 0.5321
# Batch [75/157] - Loss: 0.5483
# Batch [76/157] - Loss: 0.5337
# Batch [77/157] - Loss: 0.5473
# Batch [78/157] - Loss: 0.5356
# Batch [79/157] - Loss: 0.5585
# Batch [80/157] - Loss: 0.5605
# Batch [81/157] - Loss: 0.5179
# Batch [82/157] - Loss: 0.5426
# Batch [83/157] - Loss: 0.5480
# Batch [84/157] - Loss: 0.5323
# Batch [85/157] - Loss: 0.5432
# Batch [86/157] - Loss: 0.5364
# Batch [87/157] - Loss: 0.5358
# Batch [88/157] - Loss: 0.5522
# Batch [89/157] - Loss: 0.5451
# Batch [90/157] - Loss: 0.5158
# Batch [91/157] - Loss: 0.5284
# Batch [92/157] - Loss: 0.5307
# Batch [93/157] - Loss: 0.5489
# Batch [94/157] - Loss: 0.5121
# Batch [95/157] - Loss: 0.5214
# Batch [96/157] - Loss: 0.5161
# Batch [97/157] - Loss: 0.5274
# Batch [98/157] - Loss: 0.5257
# Batch [99/157] - Loss: 0.5244
# Batch [100/157] - Loss: 0.5271
# Batch [101/157] - Loss: 0.5511
# Batch [102/157] - Loss: 0.5529
# Batch [103/157] - Loss: 0.5466
# Batch [104/157] - Loss: 0.5450
# Batch [105/157] - Loss: 0.5140
# Batch [106/157] - Loss: 0.5496
# Batch [107/157] - Loss: 0.5335
# Batch [108/157] - Loss: 0.5356
# Batch [109/157] - Loss: 0.5298
# Batch [110/157] - Loss: 0.5202
# Batch [111/157] - Loss: 0.5350
# Batch [112/157] - Loss: 0.5373
# Batch [113/157] - Loss: 0.5286
# Batch [114/157] - Loss: 0.5280
# Batch [115/157] - Loss: 0.5848
# Batch [116/157] - Loss: 0.5454
# Batch [117/157] - Loss: 0.5188
# Batch [118/157] - Loss: 0.5373
# Batch [119/157] - Loss: 0.5204
# Batch [120/157] - Loss: 0.5241
# Batch [121/157] - Loss: 0.5337
# Batch [122/157] - Loss: 0.5427
# Batch [123/157] - Loss: 0.5352
# Batch [124/157] - Loss: 0.5198
# Batch [125/157] - Loss: 0.5455
# Batch [126/157] - Loss: 0.5520
# Batch [127/157] - Loss: 0.5413
# Batch [128/157] - Loss: 0.5081
# Batch [129/157] - Loss: 0.5162
# Batch [130/157] - Loss: 0.5301
# Batch [131/157] - Loss: 0.5657
# Batch [132/157] - Loss: 0.5461
# Batch [133/157] - Loss: 0.5370
# Batch [134/157] - Loss: 0.5219
# Batch [135/157] - Loss: 0.5262
# Batch [136/157] - Loss: 0.5132
# Batch [137/157] - Loss: 0.5183
# Batch [138/157] - Loss: 0.5322
# Batch [139/157] - Loss: 0.5264
# Batch [140/157] - Loss: 0.5211
# Batch [141/157] - Loss: 0.5438
# Batch [142/157] - Loss: 0.5413
# Batch [143/157] - Loss: 0.5494
# Batch [144/157] - Loss: 0.5164
# Batch [145/157] - Loss: 0.5299
# Batch [146/157] - Loss: 0.5353
# Batch [147/157] - Loss: 0.5225
# Batch [148/157] - Loss: 0.5396
# Batch [149/157] - Loss: 0.5625
# Batch [150/157] - Loss: 0.5422
# Batch [151/157] - Loss: 0.5537
# Batch [152/157] - Loss: 0.5544
# Batch [153/157] - Loss: 0.5294
# Batch [154/157] - Loss: 0.5463
# Batch [155/157] - Loss: 0.5575
# Batch [156/157] - Loss: 0.5255
# Batch [157/157] - Loss: 0.5112
# Epoch [2/20] Train Loss: 0.5397 | Train Acc: 98.51% Val Loss: 0.5286 | Val Acc: 98.80%
# Validation loss improved to 0.5286.
#
# Epoch 3/20
# ------------------------------
# Batch [1/157] - Loss: 0.5084
# Batch [2/157] - Loss: 0.5374
# Batch [3/157] - Loss: 0.5216
# Batch [4/157] - Loss: 0.5264
# Batch [5/157] - Loss: 0.5152
# Batch [6/157] - Loss: 0.5118
# Batch [7/157] - Loss: 0.5336
# Batch [8/157] - Loss: 0.5127
# Batch [9/157] - Loss: 0.5333
# Batch [10/157] - Loss: 0.5227
# Batch [11/157] - Loss: 0.5534
# Batch [12/157] - Loss: 0.5230
# Batch [13/157] - Loss: 0.5601
# Batch [14/157] - Loss: 0.5469
# Batch [15/157] - Loss: 0.5355
# Batch [16/157] - Loss: 0.5542
# Batch [17/157] - Loss: 0.5457
# Batch [18/157] - Loss: 0.5333
# Batch [19/157] - Loss: 0.5410
# Batch [20/157] - Loss: 0.5240
# Batch [21/157] - Loss: 0.5148
# Batch [22/157] - Loss: 0.5357
# Batch [23/157] - Loss: 0.5252
# Batch [24/157] - Loss: 0.5172
# Batch [25/157] - Loss: 0.5382
# Batch [26/157] - Loss: 0.5117
# Batch [27/157] - Loss: 0.5179
# Batch [28/157] - Loss: 0.5189
# Batch [29/157] - Loss: 0.5240
# Batch [30/157] - Loss: 0.5310
# Batch [31/157] - Loss: 0.5162
# Batch [32/157] - Loss: 0.5522
# Batch [33/157] - Loss: 0.5407
# Batch [34/157] - Loss: 0.5651
# Batch [35/157] - Loss: 0.5319
# Batch [36/157] - Loss: 0.5659
# Batch [37/157] - Loss: 0.5468
# Batch [38/157] - Loss: 0.5142
# Batch [39/157] - Loss: 0.5324
# Batch [40/157] - Loss: 0.5316
# Batch [41/157] - Loss: 0.5207
# Batch [42/157] - Loss: 0.5068
# Batch [43/157] - Loss: 0.5313
# Batch [44/157] - Loss: 0.5235
# Batch [45/157] - Loss: 0.5455
# Batch [46/157] - Loss: 0.5358
# Batch [47/157] - Loss: 0.5312
# Batch [48/157] - Loss: 0.5227
# Batch [49/157] - Loss: 0.5402
# Batch [50/157] - Loss: 0.5183
# Batch [51/157] - Loss: 0.5256
# Batch [52/157] - Loss: 0.5198
# Batch [53/157] - Loss: 0.5202
# Batch [54/157] - Loss: 0.5292
# Batch [55/157] - Loss: 0.5345
# Batch [56/157] - Loss: 0.5244
# Batch [57/157] - Loss: 0.5190
# Batch [58/157] - Loss: 0.5194
# Batch [59/157] - Loss: 0.5178
# Batch [60/157] - Loss: 0.5373
# Batch [61/157] - Loss: 0.5304
# Batch [62/157] - Loss: 0.5188
# Batch [63/157] - Loss: 0.5337
# Batch [64/157] - Loss: 0.5280
# Batch [65/157] - Loss: 0.5220
# Batch [66/157] - Loss: 0.5656
# Batch [67/157] - Loss: 0.5395
# Batch [68/157] - Loss: 0.5382
# Batch [69/157] - Loss: 0.5262
# Batch [70/157] - Loss: 0.5168
# Batch [71/157] - Loss: 0.5765
# Batch [72/157] - Loss: 0.5310
# Batch [73/157] - Loss: 0.5252
# Batch [74/157] - Loss: 0.5182
# Batch [75/157] - Loss: 0.5179
# Batch [76/157] - Loss: 0.5577
# Batch [77/157] - Loss: 0.5593
# Batch [78/157] - Loss: 0.5319
# Batch [79/157] - Loss: 0.5606
# Batch [80/157] - Loss: 0.5174
# Batch [81/157] - Loss: 0.5675
# Batch [82/157] - Loss: 0.5161
# Batch [83/157] - Loss: 0.5384
# Batch [84/157] - Loss: 0.5265
# Batch [85/157] - Loss: 0.5274
# Batch [86/157] - Loss: 0.5286
# Batch [87/157] - Loss: 0.5566
# Batch [88/157] - Loss: 0.5099
# Batch [89/157] - Loss: 0.5340
# Batch [90/157] - Loss: 0.5287
# Batch [91/157] - Loss: 0.5107
# Batch [92/157] - Loss: 0.5305
# Batch [93/157] - Loss: 0.5201
# Batch [94/157] - Loss: 0.5331
# Batch [95/157] - Loss: 0.5249
# Batch [96/157] - Loss: 0.5297
# Batch [97/157] - Loss: 0.5319
# Batch [98/157] - Loss: 0.5289
# Batch [99/157] - Loss: 0.5198
# Batch [100/157] - Loss: 0.5258
# Batch [101/157] - Loss: 0.5173
# Batch [102/157] - Loss: 0.5389
# Batch [103/157] - Loss: 0.5206
# Batch [104/157] - Loss: 0.5567
# Batch [105/157] - Loss: 0.5372
# Batch [106/157] - Loss: 0.5389
# Batch [107/157] - Loss: 0.5428
# Batch [108/157] - Loss: 0.5179
# Batch [109/157] - Loss: 0.5275
# Batch [110/157] - Loss: 0.5328
# Batch [111/157] - Loss: 0.5340
# Batch [112/157] - Loss: 0.5381
# Batch [113/157] - Loss: 0.5167
# Batch [114/157] - Loss: 0.5229
# Batch [115/157] - Loss: 0.5298
# Batch [116/157] - Loss: 0.5135
# Batch [117/157] - Loss: 0.5324
# Batch [118/157] - Loss: 0.5265
# Batch [119/157] - Loss: 0.5197
# Batch [120/157] - Loss: 0.5535
# Batch [121/157] - Loss: 0.5369
# Batch [122/157] - Loss: 0.5611
# Batch [123/157] - Loss: 0.5437
# Batch [124/157] - Loss: 0.5131
# Batch [125/157] - Loss: 0.5262
# Batch [126/157] - Loss: 0.5542
# Batch [127/157] - Loss: 0.5281
# Batch [128/157] - Loss: 0.5538
# Batch [129/157] - Loss: 0.5376
# Batch [130/157] - Loss: 0.5477
# Batch [131/157] - Loss: 0.5268
# Batch [132/157] - Loss: 0.5215
# Batch [133/157] - Loss: 0.5312
# Batch [134/157] - Loss: 0.5618
# Batch [135/157] - Loss: 0.5349
# Batch [136/157] - Loss: 0.5620
# Batch [137/157] - Loss: 0.5229
# Batch [138/157] - Loss: 0.5271
# Batch [139/157] - Loss: 0.5486
# Batch [140/157] - Loss: 0.5173
# Batch [141/157] - Loss: 0.5634
# Batch [142/157] - Loss: 0.5639
# Batch [143/157] - Loss: 0.5469
# Batch [144/157] - Loss: 0.5215
# Batch [145/157] - Loss: 0.5456
# Batch [146/157] - Loss: 0.5663
# Batch [147/157] - Loss: 0.5190
# Batch [148/157] - Loss: 0.5305
# Batch [149/157] - Loss: 0.5665
# Batch [150/157] - Loss: 0.5785
# Batch [151/157] - Loss: 0.5443
# Batch [152/157] - Loss: 0.5317
# Batch [153/157] - Loss: 0.5714
# Batch [154/157] - Loss: 0.5191
# Batch [155/157] - Loss: 0.5582
# Batch [156/157] - Loss: 0.5470
# Batch [157/157] - Loss: 0.5708
# Epoch [3/20] Train Loss: 0.5337 | Train Acc: 98.75% Val Loss: 0.5496 | Val Acc: 97.87%
# No improvement in validation loss for 1 epoch(s).
#
# Epoch 4/20
# ------------------------------
# Batch [1/157] - Loss: 0.5548
# Batch [2/157] - Loss: 0.5200
# Batch [3/157] - Loss: 0.5268
# Batch [4/157] - Loss: 0.5479
# Batch [5/157] - Loss: 0.5141
# Batch [6/157] - Loss: 0.5432
# Batch [7/157] - Loss: 0.5215
# Batch [8/157] - Loss: 0.5552
# Batch [9/157] - Loss: 0.5219
# Batch [10/157] - Loss: 0.5330
# Batch [11/157] - Loss: 0.5197
# Batch [12/157] - Loss: 0.5469
# Batch [13/157] - Loss: 0.5380
# Batch [14/157] - Loss: 0.5391
# Batch [15/157] - Loss: 0.5213
# Batch [16/157] - Loss: 0.5494
# Batch [17/157] - Loss: 0.5375
# Batch [18/157] - Loss: 0.5470
# Batch [19/157] - Loss: 0.5556
# Batch [20/157] - Loss: 0.5265
# Batch [21/157] - Loss: 0.5297
# Batch [22/157] - Loss: 0.5231
# Batch [23/157] - Loss: 0.5587
# Batch [24/157] - Loss: 0.5151
# Batch [25/157] - Loss: 0.5302
# Batch [26/157] - Loss: 0.5461
# Batch [27/157] - Loss: 0.5667
# Batch [28/157] - Loss: 0.5767
# Batch [29/157] - Loss: 0.5409
# Batch [30/157] - Loss: 0.5356
# Batch [31/157] - Loss: 0.5533
# Batch [32/157] - Loss: 0.5360
# Batch [33/157] - Loss: 0.5183
# Batch [34/157] - Loss: 0.5251
# Batch [35/157] - Loss: 0.5314
# Batch [36/157] - Loss: 0.5511
# Batch [37/157] - Loss: 0.5143
# Batch [38/157] - Loss: 0.5508
# Batch [39/157] - Loss: 0.5780
# Batch [40/157] - Loss: 0.5437
# Batch [41/157] - Loss: 0.5294
# Batch [42/157] - Loss: 0.5467
# Batch [43/157] - Loss: 0.5576
# Batch [44/157] - Loss: 0.5558
# Batch [45/157] - Loss: 0.5291
# Batch [46/157] - Loss: 0.5296
# Batch [47/157] - Loss: 0.5564
# Batch [48/157] - Loss: 0.5642
# Batch [49/157] - Loss: 0.5527
# Batch [50/157] - Loss: 0.5431
# Batch [51/157] - Loss: 0.5482
# Batch [52/157] - Loss: 0.5286
# Batch [53/157] - Loss: 0.5755
# Batch [54/157] - Loss: 0.5618
# Batch [55/157] - Loss: 0.5430
# Batch [56/157] - Loss: 0.5448
# Batch [57/157] - Loss: 0.5225
# Batch [58/157] - Loss: 0.5660
# Batch [59/157] - Loss: 0.5368
# Batch [60/157] - Loss: 0.5568
# Batch [61/157] - Loss: 0.5581
# Batch [62/157] - Loss: 0.5616
# Batch [63/157] - Loss: 0.5272
# Batch [64/157] - Loss: 0.5511
# Batch [65/157] - Loss: 0.5590
# Batch [66/157] - Loss: 0.5668
# Batch [67/157] - Loss: 0.5887
# Batch [68/157] - Loss: 0.5340
# Batch [69/157] - Loss: 0.5539
# Batch [70/157] - Loss: 0.5427
# Batch [71/157] - Loss: 0.5544
# Batch [72/157] - Loss: 0.5369
# Batch [73/157] - Loss: 0.5414
# Batch [74/157] - Loss: 0.5780
# Batch [75/157] - Loss: 0.5480
# Batch [76/157] - Loss: 0.5454
# Batch [77/157] - Loss: 0.5557
# Batch [78/157] - Loss: 0.5338
# Batch [79/157] - Loss: 0.5310
# Batch [80/157] - Loss: 0.5659
# Batch [81/157] - Loss: 0.5248
# Batch [82/157] - Loss: 0.5550
# Batch [83/157] - Loss: 0.5355
# Batch [84/157] - Loss: 0.5420
# Batch [85/157] - Loss: 0.5815
# Batch [86/157] - Loss: 0.5559
# Batch [87/157] - Loss: 0.5451
# Batch [88/157] - Loss: 0.5917
# Batch [89/157] - Loss: 0.5365
# Batch [90/157] - Loss: 0.5762
# Batch [91/157] - Loss: 0.5549
# Batch [92/157] - Loss: 0.5729
# Batch [93/157] - Loss: 0.5337
# Batch [94/157] - Loss: 0.5813
# Batch [95/157] - Loss: 0.5589
# Batch [96/157] - Loss: 0.5188
# Batch [97/157] - Loss: 0.5345
# Batch [98/157] - Loss: 0.5484
# Batch [99/157] - Loss: 0.5409
# Batch [100/157] - Loss: 0.5656
# Batch [101/157] - Loss: 0.5193
# Batch [102/157] - Loss: 0.5857
# Batch [103/157] - Loss: 0.5429
# Batch [104/157] - Loss: 0.5607
# Batch [105/157] - Loss: 0.5569
# Batch [106/157] - Loss: 0.5447
# Batch [107/157] - Loss: 0.5408
# Batch [108/157] - Loss: 0.5452
# Batch [109/157] - Loss: 0.5127
# Batch [110/157] - Loss: 0.5582
# Batch [111/157] - Loss: 0.5546
# Batch [112/157] - Loss: 0.5376
# Batch [113/157] - Loss: 0.5194
# Batch [114/157] - Loss: 0.5287
# Batch [115/157] - Loss: 0.5559
# Batch [116/157] - Loss: 0.5297
# Batch [117/157] - Loss: 0.5475
# Batch [118/157] - Loss: 0.5551
# Batch [119/157] - Loss: 0.5406
# Batch [120/157] - Loss: 0.5401
# Batch [121/157] - Loss: 0.5414
# Batch [122/157] - Loss: 0.5482
# Batch [123/157] - Loss: 0.5837
# Batch [124/157] - Loss: 0.5698
# Batch [125/157] - Loss: 0.5245
# Batch [126/157] - Loss: 0.5781
# Batch [127/157] - Loss: 0.5403
# Batch [128/157] - Loss: 0.5727
# Batch [129/157] - Loss: 0.5402
# Batch [130/157] - Loss: 0.5986
# Batch [131/157] - Loss: 0.5418
# Batch [132/157] - Loss: 0.5336
# Batch [133/157] - Loss: 0.5326
# Batch [134/157] - Loss: 0.5679
# Batch [135/157] - Loss: 0.5489
# Batch [136/157] - Loss: 0.5528
# Batch [137/157] - Loss: 0.5364
# Batch [138/157] - Loss: 0.5660
# Batch [139/157] - Loss: 0.5580
# Batch [140/157] - Loss: 0.5281
# Batch [141/157] - Loss: 0.5801
# Batch [142/157] - Loss: 0.5322
# Batch [143/157] - Loss: 0.5526
# Batch [144/157] - Loss: 0.5692
# Batch [145/157] - Loss: 0.5358
# Batch [146/157] - Loss: 0.5711
# Batch [147/157] - Loss: 0.5912
# Batch [148/157] - Loss: 0.5559
# Batch [149/157] - Loss: 0.5534
# Batch [150/157] - Loss: 0.5560
# Batch [151/157] - Loss: 0.5708
# Batch [152/157] - Loss: 0.5561
# Batch [153/157] - Loss: 0.5698
# Batch [154/157] - Loss: 0.5580
# Batch [155/157] - Loss: 0.5594
# Batch [156/157] - Loss: 0.5792
# Batch [157/157] - Loss: 0.5275
# Epoch [4/20] Train Loss: 0.5481 | Train Acc: 98.07% Val Loss: 0.5626 | Val Acc: 97.36%
# No improvement in validation loss for 2 epoch(s).
#
# Epoch 5/20
# ------------------------------
# Batch [1/157] - Loss: 0.5457
# Batch [2/157] - Loss: 0.5447
# Batch [3/157] - Loss: 0.5489
# Batch [4/157] - Loss: 0.5517
# Batch [5/157] - Loss: 0.5309
# Batch [6/157] - Loss: 0.5421
# Batch [7/157] - Loss: 0.5333
# Batch [8/157] - Loss: 0.5329
# Batch [9/157] - Loss: 0.5574
# Batch [10/157] - Loss: 0.5451
# Batch [11/157] - Loss: 0.5534
# Batch [12/157] - Loss: 0.5887
# Batch [13/157] - Loss: 0.5473
# Batch [14/157] - Loss: 0.5537
# Batch [15/157] - Loss: 0.5410
# Batch [16/157] - Loss: 0.5218
# Batch [17/157] - Loss: 0.5545
# Batch [18/157] - Loss: 0.5201
# Batch [19/157] - Loss: 0.5426
# Batch [20/157] - Loss: 0.5776
# Batch [21/157] - Loss: 0.5656
# Batch [22/157] - Loss: 0.5518
# Batch [23/157] - Loss: 0.5344
# Batch [24/157] - Loss: 0.5337
# Batch [25/157] - Loss: 0.5350
# Batch [26/157] - Loss: 0.5450
# Batch [27/157] - Loss: 0.5947
# Batch [28/157] - Loss: 0.5422
# Batch [29/157] - Loss: 0.5366
# Batch [30/157] - Loss: 0.5306
# Batch [31/157] - Loss: 0.5697
# Batch [32/157] - Loss: 0.5293
# Batch [33/157] - Loss: 0.5758
# Batch [34/157] - Loss: 0.5450
# Batch [35/157] - Loss: 0.5360
# Batch [36/157] - Loss: 0.5677
# Batch [37/157] - Loss: 0.5343
# Batch [38/157] - Loss: 0.5548
# Batch [39/157] - Loss: 0.5477
# Batch [40/157] - Loss: 0.5178
# Batch [41/157] - Loss: 0.5602
# Batch [42/157] - Loss: 0.5717
# Batch [43/157] - Loss: 0.5944
# Batch [44/157] - Loss: 0.5658
# Batch [45/157] - Loss: 0.6146
# Batch [46/157] - Loss: 0.5802
# Batch [47/157] - Loss: 0.5634
# Batch [48/157] - Loss: 0.5516
# Batch [49/157] - Loss: 0.5482
# Batch [50/157] - Loss: 0.5655
# Batch [51/157] - Loss: 0.5493
# Batch [52/157] - Loss: 0.5421
# Batch [53/157] - Loss: 0.5691
# Batch [54/157] - Loss: 0.5711
# Batch [55/157] - Loss: 0.5877
# Batch [56/157] - Loss: 0.5768
# Batch [57/157] - Loss: 0.5512
# Batch [58/157] - Loss: 0.5654
# Batch [59/157] - Loss: 0.5523
# Batch [60/157] - Loss: 0.5332
# Batch [61/157] - Loss: 0.5413
# Batch [62/157] - Loss: 0.5724
# Batch [63/157] - Loss: 0.5586
# Batch [64/157] - Loss: 0.5570
# Batch [65/157] - Loss: 0.5588
# Batch [66/157] - Loss: 0.5548
# Batch [67/157] - Loss: 0.5410
# Batch [68/157] - Loss: 0.5402
# Batch [69/157] - Loss: 0.5442
# Batch [70/157] - Loss: 0.5783
# Batch [71/157] - Loss: 0.5356
# Batch [72/157] - Loss: 0.5469
# Batch [73/157] - Loss: 0.5736
# Batch [74/157] - Loss: 0.5558
# Batch [75/157] - Loss: 0.5364
# Batch [76/157] - Loss: 0.5490
# Batch [77/157] - Loss: 0.5606
# Batch [78/157] - Loss: 0.5731
# Batch [79/157] - Loss: 0.5488
# Batch [80/157] - Loss: 0.5454
# Batch [81/157] - Loss: 0.5235
# Batch [82/157] - Loss: 0.5518
# Batch [83/157] - Loss: 0.5504
# Batch [84/157] - Loss: 0.5552
# Batch [85/157] - Loss: 0.5332
# Batch [86/157] - Loss: 0.5642
# Batch [87/157] - Loss: 0.5402
# Batch [88/157] - Loss: 0.5305
# Batch [89/157] - Loss: 0.5318
# Batch [90/157] - Loss: 0.5417
# Batch [91/157] - Loss: 0.5807
# Batch [92/157] - Loss: 0.5457
# Batch [93/157] - Loss: 0.5334
# Batch [94/157] - Loss: 0.5851
# Batch [95/157] - Loss: 0.5497
# Batch [96/157] - Loss: 0.5523
# Batch [97/157] - Loss: 0.5462
# Batch [98/157] - Loss: 0.5882
# Batch [99/157] - Loss: 0.5837
# Batch [100/157] - Loss: 0.5230
# Batch [101/157] - Loss: 0.5802
# Batch [102/157] - Loss: 0.5556
# Batch [103/157] - Loss: 0.5822
# Batch [104/157] - Loss: 0.5372
# Batch [105/157] - Loss: 0.5398
# Batch [106/157] - Loss: 0.5556
# Batch [107/157] - Loss: 0.5406
# Batch [108/157] - Loss: 0.5415
# Batch [109/157] - Loss: 0.5659
# Batch [110/157] - Loss: 0.6048
# Batch [111/157] - Loss: 0.5397
# Batch [112/157] - Loss: 0.5614
# Batch [113/157] - Loss: 0.5700
# Batch [114/157] - Loss: 0.5903
# Batch [115/157] - Loss: 0.5263
# Batch [116/157] - Loss: 0.5529
# Batch [117/157] - Loss: 0.5486
# Batch [118/157] - Loss: 0.5353
# Batch [119/157] - Loss: 0.5312
# Batch [120/157] - Loss: 0.5771
# Batch [121/157] - Loss: 0.5591
# Batch [122/157] - Loss: 0.5443
# Batch [123/157] - Loss: 0.5440
# Batch [124/157] - Loss: 0.5664
# Batch [125/157] - Loss: 0.5619
# Batch [126/157] - Loss: 0.6011
# Batch [127/157] - Loss: 0.5335
# Batch [128/157] - Loss: 0.5508
# Batch [129/157] - Loss: 0.5667
# Batch [130/157] - Loss: 0.5647
# Batch [131/157] - Loss: 0.5571
# Batch [132/157] - Loss: 0.5520
# Batch [133/157] - Loss: 0.5803
# Batch [134/157] - Loss: 0.5609
# Batch [135/157] - Loss: 0.5403
# Batch [136/157] - Loss: 0.5801
# Batch [137/157] - Loss: 0.5782
# Batch [138/157] - Loss: 0.6009
# Batch [139/157] - Loss: 0.5507
# Batch [140/157] - Loss: 0.5641
# Batch [141/157] - Loss: 0.5817
# Batch [142/157] - Loss: 0.5613
# Batch [143/157] - Loss: 0.5520
# Batch [144/157] - Loss: 0.6075
# Batch [145/157] - Loss: 0.5676
# Batch [146/157] - Loss: 0.5541
# Batch [147/157] - Loss: 0.5582
# Batch [148/157] - Loss: 0.5528
# Batch [149/157] - Loss: 0.5577
# Batch [150/157] - Loss: 0.5790
# Batch [151/157] - Loss: 0.5681
# Batch [152/157] - Loss: 0.5826
# Batch [153/157] - Loss: 0.5546
# Batch [154/157] - Loss: 0.5584
# Batch [155/157] - Loss: 0.5290
# Batch [156/157] - Loss: 0.5259
# Batch [157/157] - Loss: 0.5657
# Epoch [5/20] Train Loss: 0.5555 | Train Acc: 97.79% Val Loss: 0.5919 | Val Acc: 96.30%
# No improvement in validation loss for 3 epoch(s).
#
# Epoch 6/20
# ------------------------------
# Batch [1/157] - Loss: 0.5467
# Batch [2/157] - Loss: 0.5638
# Batch [3/157] - Loss: 0.5482
# Batch [4/157] - Loss: 0.5536
# Batch [5/157] - Loss: 0.6352
# Batch [6/157] - Loss: 0.5614
# Batch [7/157] - Loss: 0.5713
# Batch [8/157] - Loss: 0.5420
# Batch [9/157] - Loss: 0.5903
# Batch [10/157] - Loss: 0.5453
# Batch [11/157] - Loss: 0.5493
# Batch [12/157] - Loss: 0.5359
# Batch [13/157] - Loss: 0.5874
# Batch [14/157] - Loss: 0.5774
# Batch [15/157] - Loss: 0.5799
# Batch [16/157] - Loss: 0.5644
# Batch [17/157] - Loss: 0.5758
# Batch [18/157] - Loss: 0.6022
# Batch [19/157] - Loss: 0.5514
# Batch [20/157] - Loss: 0.5813
# Batch [21/157] - Loss: 0.5389
# Batch [22/157] - Loss: 0.5611
# Batch [23/157] - Loss: 0.5687
# Batch [24/157] - Loss: 0.5972
# Batch [25/157] - Loss: 0.5838
# Batch [26/157] - Loss: 0.5714
# Batch [27/157] - Loss: 0.6041
# Batch [28/157] - Loss: 0.6105
# Batch [29/157] - Loss: 0.5837
# Batch [30/157] - Loss: 0.5669
# Batch [31/157] - Loss: 0.5712
# Batch [32/157] - Loss: 0.5907
# Batch [33/157] - Loss: 0.5773
# Batch [34/157] - Loss: 0.5482
# Batch [35/157] - Loss: 0.5463
# Batch [36/157] - Loss: 0.5503
# Batch [37/157] - Loss: 0.5510
# Batch [38/157] - Loss: 0.5893
# Batch [39/157] - Loss: 0.5426
# Batch [40/157] - Loss: 0.6066
# Batch [41/157] - Loss: 0.5771
# Batch [42/157] - Loss: 0.5516
# Batch [43/157] - Loss: 0.5327
# Batch [44/157] - Loss: 0.5643
# Batch [45/157] - Loss: 0.5704
# Batch [46/157] - Loss: 0.5704
# Batch [47/157] - Loss: 0.5634
# Batch [48/157] - Loss: 0.5429
# Batch [49/157] - Loss: 0.5619
# Batch [50/157] - Loss: 0.5251
# Batch [51/157] - Loss: 0.5366
# Batch [52/157] - Loss: 0.5371
# Batch [53/157] - Loss: 0.5898
# Batch [54/157] - Loss: 0.5542
# Batch [55/157] - Loss: 0.5242
# Batch [56/157] - Loss: 0.5726
# Batch [57/157] - Loss: 0.5349
# Batch [58/157] - Loss: 0.5644
# Batch [59/157] - Loss: 0.5623
# Batch [60/157] - Loss: 0.5524
# Batch [61/157] - Loss: 0.5663
# Batch [62/157] - Loss: 0.5900
# Batch [63/157] - Loss: 0.5457
# Batch [64/157] - Loss: 0.6035
# Batch [65/157] - Loss: 0.5812
# Batch [66/157] - Loss: 0.5381
# Batch [67/157] - Loss: 0.5563
# Batch [68/157] - Loss: 0.5445
# Batch [69/157] - Loss: 0.5444
# Batch [70/157] - Loss: 0.5312
# Batch [71/157] - Loss: 0.5500
# Batch [72/157] - Loss: 0.5576
# Batch [73/157] - Loss: 0.5476
# Batch [74/157] - Loss: 0.5420
# Batch [75/157] - Loss: 0.5705
# Batch [76/157] - Loss: 0.5664
# Batch [77/157] - Loss: 0.5551
# Batch [78/157] - Loss: 0.5823
# Batch [79/157] - Loss: 0.6139
# Batch [80/157] - Loss: 0.5521
# Batch [81/157] - Loss: 0.5498
# Batch [82/157] - Loss: 0.5945
# Batch [83/157] - Loss: 0.5632
# Batch [84/157] - Loss: 0.5977
# Batch [85/157] - Loss: 0.6095
# Batch [86/157] - Loss: 0.5904
# Batch [87/157] - Loss: 0.5624
# Batch [88/157] - Loss: 0.5868
# Batch [89/157] - Loss: 0.5838
# Batch [90/157] - Loss: 0.5820
# Batch [91/157] - Loss: 0.5825
# Batch [92/157] - Loss: 0.5564
# Batch [93/157] - Loss: 0.5525
# Batch [94/157] - Loss: 0.5459
# Batch [95/157] - Loss: 0.5829
# Batch [96/157] - Loss: 0.5881
# Batch [97/157] - Loss: 0.5830
# Batch [98/157] - Loss: 0.5591
# Batch [99/157] - Loss: 0.5909
# Batch [100/157] - Loss: 0.5668
# Batch [101/157] - Loss: 0.5787
# Batch [102/157] - Loss: 0.5787
# Batch [103/157] - Loss: 0.5681
# Batch [104/157] - Loss: 0.6087
# Batch [105/157] - Loss: 0.5662
# Batch [106/157] - Loss: 0.5810
# Batch [107/157] - Loss: 0.5320
# Batch [108/157] - Loss: 0.5405
# Batch [109/157] - Loss: 0.5522
# Batch [110/157] - Loss: 0.5942
# Batch [111/157] - Loss: 0.6360
# Batch [112/157] - Loss: 0.6171
# Batch [113/157] - Loss: 0.5610
# Batch [114/157] - Loss: 0.5600
# Batch [115/157] - Loss: 0.5422
# Batch [116/157] - Loss: 0.5773
# Batch [117/157] - Loss: 0.5688
# Batch [118/157] - Loss: 0.5448
# Batch [119/157] - Loss: 0.5692
# Batch [120/157] - Loss: 0.5523
# Batch [121/157] - Loss: 0.5794
# Batch [122/157] - Loss: 0.5722
# Batch [123/157] - Loss: 0.5469
# Batch [124/157] - Loss: 0.6040
# Batch [125/157] - Loss: 0.5482
# Batch [126/157] - Loss: 0.5509
# Batch [127/157] - Loss: 0.5823
# Batch [128/157] - Loss: 0.5548
# Batch [129/157] - Loss: 0.5728
# Batch [130/157] - Loss: 0.5829
# Batch [131/157] - Loss: 0.5789
# Batch [132/157] - Loss: 0.5649
# Batch [133/157] - Loss: 0.5814
# Batch [134/157] - Loss: 0.5539
# Batch [135/157] - Loss: 0.5647
# Batch [136/157] - Loss: 0.5969
# Batch [137/157] - Loss: 0.6145
# Batch [138/157] - Loss: 0.5854
# Batch [139/157] - Loss: 0.5292
# Batch [140/157] - Loss: 0.6119
# Batch [141/157] - Loss: 0.5491
# Batch [142/157] - Loss: 0.5824
# Batch [143/157] - Loss: 0.6028
# Batch [144/157] - Loss: 0.5576
# Batch [145/157] - Loss: 0.6050
# Batch [146/157] - Loss: 0.5989
# Batch [147/157] - Loss: 0.5463
# Batch [148/157] - Loss: 0.5951
# Batch [149/157] - Loss: 0.5742
# Batch [150/157] - Loss: 0.5575
# Batch [151/157] - Loss: 0.5558
# Batch [152/157] - Loss: 0.5441
# Batch [153/157] - Loss: 0.5845
# Batch [154/157] - Loss: 0.5653
# Batch [155/157] - Loss: 0.6235
# Batch [156/157] - Loss: 0.5882
# Batch [157/157] - Loss: 0.5819
# Epoch [6/20] Train Loss: 0.5693 | Train Acc: 97.32% Val Loss: 0.6001 | Val Acc: 95.89%
# No improvement in validation loss for 4 epoch(s).
#
# Epoch 7/20
# ------------------------------
# Batch [1/157] - Loss: 0.5397
# Batch [2/157] - Loss: 0.5696
# Batch [3/157] - Loss: 0.5358
# Batch [4/157] - Loss: 0.5566
# Batch [5/157] - Loss: 0.5368
# Batch [6/157] - Loss: 0.5826
# Batch [7/157] - Loss: 0.5733
# Batch [8/157] - Loss: 0.5310
# Batch [9/157] - Loss: 0.5472
# Batch [10/157] - Loss: 0.5629
# Batch [11/157] - Loss: 0.5556
# Batch [12/157] - Loss: 0.5541
# Batch [13/157] - Loss: 0.5353
# Batch [14/157] - Loss: 0.5386
# Batch [15/157] - Loss: 0.5582
# Batch [16/157] - Loss: 0.5423
# Batch [17/157] - Loss: 0.5602
# Batch [18/157] - Loss: 0.6283
# Batch [19/157] - Loss: 0.5677
# Batch [20/157] - Loss: 0.5651
# Batch [21/157] - Loss: 0.5462
# Batch [22/157] - Loss: 0.5508
# Batch [23/157] - Loss: 0.5557
# Batch [24/157] - Loss: 0.6088
# Batch [25/157] - Loss: 0.5630
# Batch [26/157] - Loss: 0.5544
# Batch [27/157] - Loss: 0.5858
# Batch [28/157] - Loss: 0.5574
# Batch [29/157] - Loss: 0.5688
# Batch [30/157] - Loss: 0.5588
# Batch [31/157] - Loss: 0.5284
# Batch [32/157] - Loss: 0.5740
# Batch [33/157] - Loss: 0.5422
# Batch [34/157] - Loss: 0.5501
# Batch [35/157] - Loss: 0.5500
# Batch [36/157] - Loss: 0.5569
# Batch [37/157] - Loss: 0.5390
# Batch [38/157] - Loss: 0.6010
# Batch [39/157] - Loss: 0.5332
# Batch [40/157] - Loss: 0.5307
# Batch [41/157] - Loss: 0.5242
# Batch [42/157] - Loss: 0.5575
# Batch [43/157] - Loss: 0.5398
# Batch [44/157] - Loss: 0.5278
# Batch [45/157] - Loss: 0.5268
# Batch [46/157] - Loss: 0.5403
# Batch [47/157] - Loss: 0.5558
# Batch [48/157] - Loss: 0.5640
# Batch [49/157] - Loss: 0.5582
# Batch [50/157] - Loss: 0.5636
# Batch [51/157] - Loss: 0.5632
# Batch [52/157] - Loss: 0.5932
# Batch [53/157] - Loss: 0.5320
# Batch [54/157] - Loss: 0.5290
# Batch [55/157] - Loss: 0.5403
# Batch [56/157] - Loss: 0.5768
# Batch [57/157] - Loss: 0.5363
# Batch [58/157] - Loss: 0.5565
# Batch [59/157] - Loss: 0.5323
# Batch [60/157] - Loss: 0.5421
# Batch [61/157] - Loss: 0.5641
# Batch [62/157] - Loss: 0.5437
# Batch [63/157] - Loss: 0.5538
# Batch [64/157] - Loss: 0.5513
# Batch [65/157] - Loss: 0.5544
# Batch [66/157] - Loss: 0.5765
# Batch [67/157] - Loss: 0.5594
# Batch [68/157] - Loss: 0.5496
# Batch [69/157] - Loss: 0.5655
# Batch [70/157] - Loss: 0.5451
# Batch [71/157] - Loss: 0.5430
# Batch [72/157] - Loss: 0.5335
# Batch [73/157] - Loss: 0.5877
# Batch [74/157] - Loss: 0.5579
# Batch [75/157] - Loss: 0.5437
# Batch [76/157] - Loss: 0.5529
# Batch [77/157] - Loss: 0.5366
# Batch [78/157] - Loss: 0.5441
# Batch [79/157] - Loss: 0.5552
# Batch [80/157] - Loss: 0.5597
# Batch [81/157] - Loss: 0.5578
# Batch [82/157] - Loss: 0.5555
# Batch [83/157] - Loss: 0.5444
# Batch [84/157] - Loss: 0.5471
# Batch [85/157] - Loss: 0.5427
# Batch [86/157] - Loss: 0.5301
# Batch [87/157] - Loss: 0.5463
# Batch [88/157] - Loss: 0.5693
# Batch [89/157] - Loss: 0.5462
# Batch [90/157] - Loss: 0.5661
# Batch [91/157] - Loss: 0.5270
# Batch [92/157] - Loss: 0.5405
# Batch [93/157] - Loss: 0.5376
# Batch [94/157] - Loss: 0.5158
# Batch [95/157] - Loss: 0.5586
# Batch [96/157] - Loss: 0.5564
# Batch [97/157] - Loss: 0.5547
# Batch [98/157] - Loss: 0.5400
# Batch [99/157] - Loss: 0.5623
# Batch [100/157] - Loss: 0.5446
# Batch [101/157] - Loss: 0.5781
# Batch [102/157] - Loss: 0.5277
# Batch [103/157] - Loss: 0.5326
# Batch [104/157] - Loss: 0.5211
# Batch [105/157] - Loss: 0.5435
# Batch [106/157] - Loss: 0.5312
# Batch [107/157] - Loss: 0.5579
# Batch [108/157] - Loss: 0.5505
# Batch [109/157] - Loss: 0.5931
# Batch [110/157] - Loss: 0.5472
# Batch [111/157] - Loss: 0.5629
# Batch [112/157] - Loss: 0.5532
# Batch [113/157] - Loss: 0.5386
# Batch [114/157] - Loss: 0.5413
# Batch [115/157] - Loss: 0.5820
# Batch [116/157] - Loss: 0.5606
# Batch [117/157] - Loss: 0.5370
# Batch [118/157] - Loss: 0.5632
# Batch [119/157] - Loss: 0.5738
# Batch [120/157] - Loss: 0.5321
# Batch [121/157] - Loss: 0.5749
# Batch [122/157] - Loss: 0.5713
# Batch [123/157] - Loss: 0.5310
# Batch [124/157] - Loss: 0.5377
# Batch [125/157] - Loss: 0.5869
# Batch [126/157] - Loss: 0.5803
# Batch [127/157] - Loss: 0.5591
# Batch [128/157] - Loss: 0.5624
# Batch [129/157] - Loss: 0.5449
# Batch [130/157] - Loss: 0.5545
# Batch [131/157] - Loss: 0.5587
# Batch [132/157] - Loss: 0.5707
# Batch [133/157] - Loss: 0.5748
# Batch [134/157] - Loss: 0.5315
# Batch [135/157] - Loss: 0.5721
# Batch [136/157] - Loss: 0.5342
# Batch [137/157] - Loss: 0.5440
# Batch [138/157] - Loss: 0.5587
# Batch [139/157] - Loss: 0.5670
# Batch [140/157] - Loss: 0.5395
# Batch [141/157] - Loss: 0.5336
# Batch [142/157] - Loss: 0.5457
# Batch [143/157] - Loss: 0.5350
# Batch [144/157] - Loss: 0.5358
# Batch [145/157] - Loss: 0.5365
# Batch [146/157] - Loss: 0.5668
# Batch [147/157] - Loss: 0.5372
# Batch [148/157] - Loss: 0.5622
# Batch [149/157] - Loss: 0.5825
# Batch [150/157] - Loss: 0.5535
# Batch [151/157] - Loss: 0.5664
# Batch [152/157] - Loss: 0.5867
# Batch [153/157] - Loss: 0.5273
# Batch [154/157] - Loss: 0.5486
# Batch [155/157] - Loss: 0.5547
# Batch [156/157] - Loss: 0.5492
# Batch [157/157] - Loss: 0.6599
# Epoch [7/20] Train Loss: 0.5532 | Train Acc: 98.00% Val Loss: 0.5913 | Val Acc: 96.37%
# No improvement in validation loss for 5 epoch(s).
# Early stopping triggered.
# Early stopping triggered.
# <All keys matched successfully>

# %%
model.load_state_dict(best_model_state)

model.eval()
test_loss = 0.0
test_correct = 0
test_total = 0
with torch.no_grad():
    for inputs, targets in test_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        
        test_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        test_total += targets.size(0)
        test_correct += predicted.eq(targets).sum().item()

test_loss /= test_total
test_acc = 100. * test_correct / test_total

print(f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.2f}%")
# Out:
# Test Loss: 0.5809 | Test Acc: 96.65%
